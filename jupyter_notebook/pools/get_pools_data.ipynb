# %%
import pandas as pd
import numpy as np
import json
import csv
import requests
import datetime as dt
from sqlalchemy import create_engine
from sqlalchemy import MetaData

# %%
def connect_db(database='pools'):
    user='root'
    password='240699'
    host='localhost'
    database=database
    

    # Connect to the database
    engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}/{database}")
    try:
        connection = engine.connect()
        return connection
    except Exception as e:
        raise e

# %%
response = requests.get('https://yields.llama.fi/pools')
data = response.json()

# %%
data
# Out:
# {'status': 'success',
#  'data': [{'chain': 'Ethereum',
#    'project': 'lido',
#    'symbol': 'STETH',
#    'tvlUsd': 19972627403,
#    'apyBase': 3.6,
#    'apyReward': None,
#    'apy': 3.6,
#    'rewardTokens': None,
#    'pool': '747c1d2a-c668-4682-b9f9-296708a3dd90',
#    'apyPct1D': None,
#    'apyPct7D': None,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 55.00000000000001,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 4.4325,
#    'sigma': 0.04738,
#    'count': 587,
#    'outlier': False,
#    'underlyingTokens': ['0x0000000000000000000000000000000000000000'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 3.78182,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Avalanche',
#    'project': 'joe-v2.1',
#    'symbol': 'DWEEB-WAVAX',
#    'tvlUsd': 18101870530,
#    'apyBase': 0,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': '35768c30-eae6-468f-8eb1-17fb707f851f',
#    'apyPct1D': None,
#    'apyPct7D': None,
#    'apyPct30D': None,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 0,
#    'sigma': 0,
#    'count': 1,
#    'outlier': False,
#    'underlyingTokens': ['0x3aa9d7ff037a2cf76162ec6001452b1c3261ab3e',
#     '0xb31f66aa3c1e785363f0875a1b74e27b85fd66c7'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': 14.90332,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Solana',
#    'project': 'raydium',
#    'symbol': 'SOL-UNKNOWN',
#    'tvlUsd': 11615990503,
#    'apyBase': 0,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': '943cbe42-0c69-4a92-97db-86f732a3449a',
#    'apyPct1D': None,
#    'apyPct7D': 0,
#    'apyPct30D': None,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 0,
#    'sigma': 0,
#    'count': 1,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 53.309,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Tron',
#    'project': 'justlend',
#    'symbol': 'BTC',
#    'tvlUsd': 4414398191,
#    'apyBase': 0.0005,
#    'apyReward': 0,
#    'apy': 0.0005,
#    'rewardTokens': ['TPYmHEhy5n8TCEfYGqW2rPxsghSfzghPDn'],
#    'pool': '71418c17-d2aa-4eff-b68a-806fff9ec951',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 8e-05,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 81,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 0.02849,
#    'sigma': 0.00082,
#    'count': 544,
#    'outlier': False,
#    'underlyingTokens': ['TN3W4H6rK2ce4vX9YnFQHwKENnHjoxb3m9'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0.00049,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'rocket-pool',
#    'symbol': 'RETH',
#    'tvlUsd': 2535309195,
#    'apyBase': 3.11568,
#    'apyReward': None,
#    'apy': 3.11568,
#    'rewardTokens': None,
#    'pool': 'd4b3c522-6127-4b89-bedf-83641cdcd2eb',
#    'apyPct1D': 0.02136,
#    'apyPct7D': -0.08511,
#    'apyPct30D': -0.08526,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 62,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 3.83926,
#    'sigma': 0.03908,
#    'count': 350,
#    'outlier': False,
#    'underlyingTokens': ['0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 3.43859,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Solana',
#    'project': 'raydium',
#    'symbol': 'UNKNOWN-SOL',
#    'tvlUsd': 2042419699,
#    'apyBase': 0,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': '49536d17-821c-4b1c-b9bb-8e0be5b45951',
#    'apyPct1D': None,
#    'apyPct7D': None,
#    'apyPct30D': None,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 0,
#    'sigma': 0,
#    'count': 1,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Solana',
#    'project': 'raydium',
#    'symbol': 'UNKNOWN-SOL',
#    'tvlUsd': 2033899310,
#    'apyBase': 0,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': 'b975e72c-799d-45fb-9128-62002aa1914e',
#    'apyPct1D': None,
#    'apyPct7D': None,
#    'apyPct30D': None,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 0,
#    'sigma': 0,
#    'count': 1,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'aave-v3',
#    'symbol': 'WSTETH',
#    'tvlUsd': 2029482652,
#    'apyBase': 0.00281,
#    'apyReward': None,
#    'apy': 0.00281,
#    'rewardTokens': None,
#    'pool': 'e6435aae-cbe9-4d26-ab2c-a4d533db9972',
#    'apyPct1D': 3e-05,
#    'apyPct7D': -0.00033,
#    'apyPct30D': -0.00142,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 54,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 0.00638,
#    'sigma': 0.0004,
#    'count': 329,
#    'outlier': False,
#    'underlyingTokens': ['0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0.00335,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Tron',
#    'project': 'justlend',
#    'symbol': 'WSTUSDT',
#    'tvlUsd': 1804198422,
#    'apyBase': 0,
#    'apyReward': 0,
#    'apy': 0,
#    'rewardTokens': ['TPYmHEhy5n8TCEfYGqW2rPxsghSfzghPDn'],
#    'pool': '00bce708-f7e2-4af6-9488-be0089a660a6',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': True,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 2e-05,
#    'sigma': 1e-05,
#    'count': 136,
#    'outlier': False,
#    'underlyingTokens': ['TGkxzkDKyMeq2T7edKnyjZoFypyzjkkssq'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'makerdao',
#    'symbol': 'WETH',
#    'tvlUsd': 1677834958,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': '51d2f8d4-1fb5-4f6b-938b-e9cd17ca1ceb',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': 'ETH-C',
#    'mu': 0,
#    'sigma': 0,
#    'count': 430,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'makerdao',
#    'symbol': 'DAI',
#    'tvlUsd': 1484403491,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 5,
#    'rewardTokens': None,
#    'pool': 'c8a24fee-ec00-4f38-86c0-9f6daebc4225',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': True,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Down',
#     'predictedProbability': 66,
#     'binnedConfidence': 2},
#    'poolMeta': 'DSR',
#    'mu': 2.85841,
#    'sigma': 0.10614,
#    'count': 391,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 5,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'binance-staked-eth',
#    'symbol': 'WBETH',
#    'tvlUsd': 1422447588,
#    'apyBase': 3.03461,
#    'apyReward': None,
#    'apy': 3.03461,
#    'rewardTokens': None,
#    'pool': '80b8bf92-b953-4c20-98ea-c9653ef2bb98',
#    'apyPct1D': 0.05804,
#    'apyPct7D': -0.35697,
#    'apyPct30D': -0.94827,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 70,
#     'binnedConfidence': 2},
#    'poolMeta': None,
#    'mu': 3.80258,
#    'sigma': 0.02634,
#    'count': 200,
#    'outlier': False,
#    'underlyingTokens': ['0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 3.54605,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'spark',
#    'symbol': 'WSTETH',
#    'tvlUsd': 1250146840,
#    'apyBase': 3e-05,
#    'apyReward': None,
#    'apy': 3e-05,
#    'rewardTokens': None,
#    'pool': '3b45941c-16cb-48c5-a490-16c6c4f1d86a',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 56.99999999999999,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 0.00602,
#    'sigma': 0.00055,
#    'count': 236,
#    'outlier': False,
#    'underlyingTokens': ['0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0.00012,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Arbitrum',
#    'project': 'sushiswap',
#    'symbol': 'QUICKI-WETH',
#    'tvlUsd': 1155693266,
#    'apyBase': 0,
#    'apyReward': 0,
#    'apy': 0,
#    'rewardTokens': [],
#    'pool': '46b56ecf-f1df-456c-b192-1d29a26e9bbb',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 9.2246,
#    'sigma': 0.7385,
#    'count': 323,
#    'outlier': False,
#    'underlyingTokens': ['0x6d038130b9b379a373b1d33a29d5904ed1bb9026',
#     '0x82af49447d8a07e3bd95bd0d56f35241523fbab1'],
#    'il7d': -0.14156,
#    'apyBase7d': 0,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'makerdao',
#    'symbol': 'WETH',
#    'tvlUsd': 1067618944,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': '54600482-cfb9-4dd9-a73b-342cffd4644a',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': 'ETH-A',
#    'mu': 0,
#    'sigma': 0,
#    'count': 430,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'makerdao',
#    'symbol': 'WSTETH',
#    'tvlUsd': 1044527104,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': '51eb4b5c-6d62-42fe-99d6-92ba6eecd2d5',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': 'WSTETH-A',
#    'mu': 0,
#    'sigma': 0,
#    'count': 430,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'makerdao',
#    'symbol': 'WSTETH',
#    'tvlUsd': 1027570428,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': 'ccc467d1-bdf5-4062-81cd-7aed7dd9050b',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': 'WSTETH-B',
#    'mu': 0,
#    'sigma': 0,
#    'count': 430,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'aave-v2',
#    'symbol': 'STETH',
#    'tvlUsd': 979332691,
#    'apyBase': 0,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': '0e458a5b-fd99-4667-8706-dd938934cb0c',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 0,
#    'sigma': 0,
#    'count': 521,
#    'outlier': False,
#    'underlyingTokens': ['0xae7ab96520DE3A18E5e111B5EaAb095312D7fE84'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'liquity',
#    'symbol': 'WETH',
#    'tvlUsd': 741587724,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': 'ddd25534-e3d5-4e4e-9b99-d3102323ac61',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 0,
#    'sigma': 0,
#    'count': 431,
#    'outlier': False,
#    'underlyingTokens': ['0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'frax-ether',
#    'symbol': 'SFRXETH',
#    'tvlUsd': 710841155,
#    'apyBase': 3.89468,
#    'apyReward': None,
#    'apy': 3.89468,
#    'rewardTokens': None,
#    'pool': '77020688-e1f9-443c-9388-e51ace15cc32',
#    'apyPct1D': -0.00254,
#    'apyPct7D': -0.39065,
#    'apyPct30D': 0.14427,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Down',
#     'predictedProbability': 53,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 5.39662,
#    'sigma': 0.07721,
#    'count': 350,
#    'outlier': False,
#    'underlyingTokens': ['0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 3.97009,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'aave-v2',
#    'symbol': 'WBTC',
#    'tvlUsd': 643493902,
#    'apyBase': 0.076,
#    'apyReward': None,
#    'apy': 0.076,
#    'rewardTokens': None,
#    'pool': '40e0d8b7-5eba-4d6c-a3c2-9ac375bcd4bf',
#    'apyPct1D': 0.00098,
#    'apyPct7D': 0.0023,
#    'apyPct30D': -0.01798,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 79,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 0.11769,
#    'sigma': 0.0027,
#    'count': 521,
#    'outlier': False,
#    'underlyingTokens': ['0x2260FAC5E5542a773Aa44fBCfeDf7C193bc2C599'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0.08567,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Solana',
#    'project': 'orca',
#    'symbol': 'SOL-WSB',
#    'tvlUsd': 618622205,
#    'apyBase': 182.08675,
#    'apyReward': None,
#    'apy': 182.08675,
#    'rewardTokens': [],
#    'pool': 'dea3d4ed-6e1a-4daf-9376-e28d821a3b29',
#    'apyPct1D': None,
#    'apyPct7D': None,
#    'apyPct30D': None,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 182.08675,
#    'sigma': 0,
#    'count': 1,
#    'outlier': True,
#    'underlyingTokens': ['So11111111111111111111111111111111111111112',
#     '95mFzbDT1YqpnbdqY85nFbvFoy5F1NMdj9kJKJraGGZg'],
#    'il7d': None,
#    'apyBase7d': 202.57292,
#    'apyMean30d': 392.67083,
#    'volumeUsd1d': 34.19843,
#    'volumeUsd7d': 187.40765,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'aave-v3',
#    'symbol': 'WBTC',
#    'tvlUsd': 613118072,
#    'apyBase': 0.03198,
#    'apyReward': None,
#    'apy': 0.03198,
#    'rewardTokens': None,
#    'pool': '7e382157-b1bc-406d-b17b-facba43b716e',
#    'apyPct1D': 0.00068,
#    'apyPct7D': -0.0224,
#    'apyPct30D': -0.08941,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 88,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 0.15988,
#    'sigma': 0.00918,
#    'count': 329,
#    'outlier': False,
#    'underlyingTokens': ['0x2260FAC5E5542a773Aa44fBCfeDf7C193bc2C599'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0.07903,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'compound-v3',
#    'symbol': 'WBTC',
#    'tvlUsd': 489921161,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': 'c1ca08e4-d618-415e-ad63-fcec58705469',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': 'USDC-pool',
#    'mu': 0,
#    'sigma': 0,
#    'count': 450,
#    'outlier': False,
#    'underlyingTokens': ['0x2260FAC5E5542a773Aa44fBCfeDf7C193bc2C599'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'compound',
#    'symbol': 'WETH',
#    'tvlUsd': 480232831,
#    'apyBase': 0.05296,
#    'apyReward': 0,
#    'apy': 0.05296,
#    'rewardTokens': [],
#    'pool': '1e5da7c6-59bb-49bd-9f97-4f4fceeffad4',
#    'apyPct1D': -0.0006,
#    'apyPct7D': 0.00065,
#    'apyPct30D': 0.0172,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 82,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 0.13327,
#    'sigma': 0.00676,
#    'count': 690,
#    'outlier': False,
#    'underlyingTokens': ['0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0.04512,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'BSC',
#    'project': 'venus-core-pool',
#    'symbol': 'BTCB',
#    'tvlUsd': 474818336,
#    'apyBase': 0.21737,
#    'apyReward': 0.03466,
#    'apy': 0.25202,
#    'rewardTokens': ['0xcf6bb5389c92bdda8a3747ddb454cb7a64626c63'],
#    'pool': '87c8ee0d-b812-47c1-803f-f91a3907079e',
#    'apyPct1D': -0.00157,
#    'apyPct7D': -0.05629,
#    'apyPct30D': -0.30983,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 89,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 0.53979,
#    'sigma': 0.01288,
#    'count': 545,
#    'outlier': False,
#    'underlyingTokens': ['0x7130d2A12B9BCbFAe4f2634d864A1Ee1Ce3Ead9c'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0.40898,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'compound',
#    'symbol': 'WBTC',
#    'tvlUsd': 471280605,
#    'apyBase': 0.00792,
#    'apyReward': 0,
#    'apy': 0.00792,
#    'rewardTokens': [],
#    'pool': '1d876729-4445-4623-8b6b-c5290db5d100',
#    'apyPct1D': 0,
#    'apyPct7D': -0.00109,
#    'apyPct30D': 0.00153,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 92,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 0.08968,
#    'sigma': 0.00586,
#    'count': 690,
#    'outlier': False,
#    'underlyingTokens': ['0x2260FAC5E5542a773Aa44fBCfeDf7C193bc2C599'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0.00798,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'coinbase-wrapped-staked-eth',
#    'symbol': 'CBETH',
#    'tvlUsd': 460743123,
#    'apyBase': 2.97276,
#    'apyReward': None,
#    'apy': 2.97276,
#    'rewardTokens': None,
#    'pool': '0f45d730-b279-4629-8e11-ccb5cc3038b4',
#    'apyPct1D': 0.07445,
#    'apyPct7D': -0.163,
#    'apyPct30D': -0.52377,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 80,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 3.89177,
#    'sigma': 0.0579,
#    'count': 349,
#    'outlier': False,
#    'underlyingTokens': ['0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 3.54433,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'aave-v2',
#    'symbol': 'WETH',
#    'tvlUsd': 414878369,
#    'apyBase': 0.94817,
#    'apyReward': None,
#    'apy': 0.94817,
#    'rewardTokens': None,
#    'pool': 'f2726d05-1f8d-4b9c-80e3-43d03d85d117',
#    'apyPct1D': -0.00375,
#    'apyPct7D': 0.00019,
#    'apyPct30D': -0.06969,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 69,
#     'binnedConfidence': 2},
#    'poolMeta': None,
#    'mu': 1.59276,
#    'sigma': 0.10732,
#    'count': 521,
#    'outlier': False,
#    'underlyingTokens': ['0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0.93472,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'BSC',
#    'project': 'binance-staked-eth',
#    'symbol': 'WBETH',
#    'tvlUsd': 392700863,
#    'apyBase': 3.03461,
#    'apyReward': None,
#    'apy': 3.03461,
#    'rewardTokens': None,
#    'pool': '566c64cb-c1ec-4027-bb67-1e9326d6d48a',
#    'apyPct1D': 0.05804,
#    'apyPct7D': -0.35697,
#    'apyPct30D': -0.94827,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 78,
#     'binnedConfidence': 2},
#    'poolMeta': None,
#    'mu': 3.80258,
#    'sigma': 0.02634,
#    'count': 200,
#    'outlier': False,
#    'underlyingTokens': ['0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 3.54605,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'mantle-staked-eth',
#    'symbol': 'METH',
#    'tvlUsd': 373216306,
#    'apyBase': 3.72148,
#    'apyReward': None,
#    'apy': 3.72148,
#    'rewardTokens': None,
#    'pool': 'b9f2f00a-ba96-4589-a171-dde979a23d87',
#    'apyPct1D': -2.18104,
#    'apyPct7D': -3.32836,
#    'apyPct30D': None,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 56.00000000000001,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 5.94204,
#    'sigma': 0.11941,
#    'count': 15,
#    'outlier': False,
#    'underlyingTokens': ['0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'],
#    'il7d': None,
#    'apyBase7d': 6.45497,
#    'apyMean30d': 6.02606,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Arbitrum',
#    'project': 'gmx-v1',
#    'symbol': 'GMX',
#    'tvlUsd': 362157491,
#    'apyBase': 2.82334,
#    'apyReward': 0,
#    'apy': 2.82334,
#    'rewardTokens': ['0xfc5A1A6EB076a2C7aD06eD22C90d7E710E35ad0a'],
#    'pool': '4df7d373-6214-4a73-9bd3-ca6e5683d846',
#    'apyPct1D': -0.02799,
#    'apyPct7D': -0.1501,
#    'apyPct30D': 1.20916,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 78,
#     'binnedConfidence': 2},
#    'poolMeta': None,
#    'mu': 9.886,
#    'sigma': 0.37058,
#    'count': 585,
#    'outlier': False,
#    'underlyingTokens': ['0xfc5A1A6EB076a2C7aD06eD22C90d7E710E35ad0a'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 3.30804,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'swell-liquid-staking',
#    'symbol': 'SWETH',
#    'tvlUsd': 326821604,
#    'apyBase': 3.25397,
#    'apyReward': None,
#    'apy': 3.25397,
#    'rewardTokens': None,
#    'pool': 'ca2acc2d-6246-44aa-ae91-8725b2c62c7c',
#    'apyPct1D': -0.08946,
#    'apyPct7D': 0.15012,
#    'apyPct30D': -0.2331,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 71,
#     'binnedConfidence': 2},
#    'poolMeta': None,
#    'mu': 3.67318,
#    'sigma': 0.04255,
#    'count': 211,
#    'outlier': False,
#    'underlyingTokens': ['0x0000000000000000000000000000000000000000'],
#    'il7d': None,
#    'apyBase7d': 3.25397,
#    'apyMean30d': 3.52105,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'makerdao',
#    'symbol': 'USDC',
#    'tvlUsd': 312029763,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': '051c1a54-df05-4bc4-9d73-c17508acae23',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': True,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': 'PSM-USDC-A',
#    'mu': 0,
#    'sigma': 0,
#    'count': 424,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Avalanche',
#    'project': 'joe-v2.1',
#    'symbol': 'DIDI-WAVAX',
#    'tvlUsd': 288054650,
#    'apyBase': 0.00039,
#    'apyReward': None,
#    'apy': 0.00039,
#    'rewardTokens': None,
#    'pool': '2cfa4eb6-dbd9-49bb-ba57-bc785bf6967c',
#    'apyPct1D': None,
#    'apyPct7D': -0.00067,
#    'apyPct30D': None,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 0.00042,
#    'sigma': 2e-05,
#    'count': 4,
#    'outlier': False,
#    'underlyingTokens': ['0xcbcd10185cb828bf6b65f828f6166140d6a92447',
#     '0xb31f66aa3c1e785363f0875a1b74e27b85fd66c7'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0.00059,
#    'volumeUsd1d': 1218.9139,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'aave-v3',
#    'symbol': 'WETH',
#    'tvlUsd': 272775980,
#    'apyBase': 1.74885,
#    'apyReward': None,
#    'apy': 1.74885,
#    'rewardTokens': None,
#    'pool': 'e880e828-ca59-4ec6-8d4f-27182a4dc23d',
#    'apyPct1D': -0.00718,
#    'apyPct7D': -0.07143,
#    'apyPct30D': -0.01867,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 95,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 1.9063,
#    'sigma': 0.01534,
#    'count': 329,
#    'outlier': False,
#    'underlyingTokens': ['0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 1.88939,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'morpho-aave',
#    'symbol': 'STETH',
#    'tvlUsd': 272258886,
#    'apyBase': 0,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': 'eab8d63d-8a8f-48cb-8027-583508831d24',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 0,
#    'sigma': 0,
#    'count': 446,
#    'outlier': False,
#    'underlyingTokens': ['0xae7ab96520de3a18e5e111b5eaab095312d7fe84'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'prisma-finance',
#    'symbol': 'WSTETH',
#    'tvlUsd': 239860477,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': ['0xda47862a83dac0c112ba89c6abc2159b95afd71c'],
#    'pool': '0caf7faa-6e69-45ad-92e5-febaef0335cb',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 0,
#    'sigma': 0,
#    'count': 56,
#    'outlier': False,
#    'underlyingTokens': ['0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'compound-v3',
#    'symbol': 'WETH',
#    'tvlUsd': 238594182,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': '072f6554-daa7-4708-80ba-371b896a89db',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': 'USDC-pool',
#    'mu': 0,
#    'sigma': 0,
#    'count': 450,
#    'outlier': False,
#    'underlyingTokens': ['0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Solana',
#    'project': 'raydium',
#    'symbol': 'UNKNOWN-SOL',
#    'tvlUsd': 231029355,
#    'apyBase': 0.04,
#    'apyReward': None,
#    'apy': 0.04,
#    'rewardTokens': None,
#    'pool': '7a7adb41-14b5-43bd-9348-7ff77e1a09ff',
#    'apyPct1D': None,
#    'apyPct7D': None,
#    'apyPct30D': None,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 0.04,
#    'sigma': 0,
#    'count': 1,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0.04,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'curve-dex',
#    'symbol': 'ETH-STETH',
#    'tvlUsd': 229076223,
#    'apyBase': 1.68,
#    'apyReward': 0.00118,
#    'apy': 1.68118,
#    'rewardTokens': ['0x5A98FcBEA516Cf06857215779Fd812CA3beF1B32',
#     '0xD533a949740bb3306d119CC777fa900bA034cd52'],
#    'pool': '57d30b9c-fc66-4ac2-b666-69ad5f410cce',
#    'apyPct1D': None,
#    'apyPct7D': -0.33011,
#    'apyPct30D': -0.25002,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Down',
#     'predictedProbability': 56.00000000000001,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 4.77195,
#    'sigma': 0.94405,
#    'count': 683,
#    'outlier': False,
#    'underlyingTokens': ['0xEeeeeEeeeEeEeeEeEeEeeEEEeeeeEeeeeeeeEEeE',
#     '0xae7ab96520DE3A18E5e111B5EaAb095312D7fE84'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 2.10478,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'makerdao',
#    'symbol': 'WETH',
#    'tvlUsd': 228815338,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': '44c94cb2-8af3-4b7a-8cb5-0784ddcf3471',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': 'ETH-B',
#    'mu': 0,
#    'sigma': 0,
#    'count': 430,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Arbitrum',
#    'project': 'gmx-v1',
#    'symbol': 'WBTC-ETH-USDC-DAI-FRAX-LINK-UNI-USDT',
#    'tvlUsd': 228464453,
#    'apyBase': 11.82511,
#    'apyReward': 0,
#    'apy': 11.82511,
#    'rewardTokens': ['0xfc5A1A6EB076a2C7aD06eD22C90d7E710E35ad0a'],
#    'pool': '825688c0-c694-4a6b-8497-177e425b7348',
#    'apyPct1D': 0.31743,
#    'apyPct7D': 1.06154,
#    'apyPct30D': 7.09695,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 79,
#     'binnedConfidence': 3},
#    'poolMeta': 'GLP',
#    'mu': 19.07962,
#    'sigma': 0.47647,
#    'count': 585,
#    'outlier': False,
#    'underlyingTokens': ['0x4277f8F2c384827B5273592FF7CeBd9f2C1ac258'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 12.88595,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Solana',
#    'project': 'raydium',
#    'symbol': 'CATRARI-SOL',
#    'tvlUsd': 228305662,
#    'apyBase': 0,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': 'dc6ab212-999e-4e03-abb9-07bdbb40a843',
#    'apyPct1D': None,
#    'apyPct7D': None,
#    'apyPct30D': None,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 0,
#    'sigma': 0,
#    'count': 1,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'uniswap-v3',
#    'symbol': 'WBTC-WETH',
#    'tvlUsd': 223875510,
#    'apyBase': 6.68539,
#    'apyReward': None,
#    'apy': 6.68539,
#    'rewardTokens': None,
#    'pool': 'c5599b3a-ea73-4017-a867-72eb971301d1',
#    'apyPct1D': 1.88744,
#    'apyPct7D': 3.99019,
#    'apyPct30D': 1.50922,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 56.00000000000001,
#     'binnedConfidence': 1},
#    'poolMeta': '0.3%',
#    'mu': 8.93695,
#    'sigma': 0.46028,
#    'count': 641,
#    'outlier': False,
#    'underlyingTokens': ['0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#     '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'],
#    'il7d': -0.05201,
#    'apyBase7d': 5.88598,
#    'apyMean30d': 6.34947,
#    'volumeUsd1d': 13668457.62837,
#    'volumeUsd7d': 97732899.38836,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'morpho-aave',
#    'symbol': 'WETH',
#    'tvlUsd': 221461823,
#    'apyBase': 2.41573,
#    'apyReward': None,
#    'apy': 2.41573,
#    'rewardTokens': None,
#    'pool': '7be52986-18c2-450f-b74b-d65fb1205bbf',
#    'apyPct1D': -0.00651,
#    'apyPct7D': -0.00239,
#    'apyPct30D': -0.08617,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 81,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 2.48477,
#    'sigma': 0.01986,
#    'count': 446,
#    'outlier': False,
#    'underlyingTokens': ['0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 2.39084,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Tron',
#    'project': 'justlend',
#    'symbol': 'USDD',
#    'tvlUsd': 214406474,
#    'apyBase': 0.06013,
#    'apyReward': 5.13721,
#    'apy': 5.19733,
#    'rewardTokens': ['TPYmHEhy5n8TCEfYGqW2rPxsghSfzghPDn'],
#    'pool': '53b3663f-9096-49df-8787-f6ea3b6d0612',
#    'apyPct1D': 0.00101,
#    'apyPct7D': -0.01478,
#    'apyPct30D': 0.0161,
#    'stablecoin': True,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Down',
#     'predictedProbability': 63,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 6.26451,
#    'sigma': 0.10214,
#    'count': 544,
#    'outlier': False,
#    'underlyingTokens': ['TPYmHEhy5n8TCEfYGqW2rPxsghSfzghPDn'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 5.19867,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'curve-dex',
#    'symbol': 'DAI-USDC-USDT',
#    'tvlUsd': 199651332,
#    'apyBase': 0.64,
#    'apyReward': 0.84269,
#    'apy': 1.48269,
#    'rewardTokens': ['0xD533a949740bb3306d119CC777fa900bA034cd52'],
#    'pool': '25171c4c-1877-449a-9f88-45a9f153ee31',
#    'apyPct1D': 0.30361,
#    'apyPct7D': -0.104,
#    'apyPct30D': 0.30539,
#    'stablecoin': True,
#    'ilRisk': 'no',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 73,
#     'binnedConfidence': 2},
#    'poolMeta': None,
#    'mu': 1.05257,
#    'sigma': 0.03941,
#    'count': 685,
#    'outlier': False,
#    'underlyingTokens': ['0x6B175474E89094C44Da98b954EedeAC495271d0F',
#     '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48',
#     '0xdAC17F958D2ee523a2206206994597C13D831ec7'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 1.85495,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'spark',
#    'symbol': 'WETH',
#    'tvlUsd': 191746444,
#    'apyBase': 1.40692,
#    'apyReward': None,
#    'apy': 1.40692,
#    'rewardTokens': None,
#    'pool': '24195b31-d749-445f-bf9e-b65aa025ebdd',
#    'apyPct1D': -0.04047,
#    'apyPct7D': -0.802,
#    'apyPct30D': -0.43438,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 83,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 1.43064,
#    'sigma': 0.03171,
#    'count': 237,
#    'outlier': False,
#    'underlyingTokens': ['0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 2.03758,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Tron',
#    'project': 'justlend',
#    'symbol': 'USDT',
#    'tvlUsd': 182894293,
#    'apyBase': 0.41936,
#    'apyReward': 0,
#    'apy': 0.41936,
#    'rewardTokens': ['TPYmHEhy5n8TCEfYGqW2rPxsghSfzghPDn'],
#    'pool': 'dac406f6-5600-437e-849d-f03daa383864',
#    'apyPct1D': -0.7009,
#    'apyPct7D': -0.20894,
#    'apyPct30D': -1.36098,
#    'stablecoin': True,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 76,
#     'binnedConfidence': 2},
#    'poolMeta': None,
#    'mu': 1.53378,
#    'sigma': 0.08317,
#    'count': 544,
#    'outlier': False,
#    'underlyingTokens': ['TR7NHqjeKQxGTCi8q8ZY4pL8otSzgjLj6t'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 1.5921,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Avalanche',
#    'project': 'benqi-lending',
#    'symbol': 'SAVAX',
#    'tvlUsd': 176527025,
#    'apyBase': 0.61135,
#    'apyReward': 2.03698,
#    'apy': 2.64833,
#    'rewardTokens': ['0x8729438eb15e2c8b576fcc6aecda6a148776c0f5',
#     '0xb31f66aa3c1e785363f0875a1b74e27b85fd66c7'],
#    'pool': 'da5e182c-b440-4b80-ab54-c1bc94a4ffd4',
#    'apyPct1D': 0.03876,
#    'apyPct7D': 0.07577,
#    'apyPct30D': 0.75549,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 90,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 3.0364,
#    'sigma': 0.0484,
#    'count': 510,
#    'outlier': False,
#    'underlyingTokens': ['0x2b2C81e08f1Af8835a78Bb2A90AE924ACE0eA4bE'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 2.48562,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'stader',
#    'symbol': 'ETHX',
#    'tvlUsd': 169266062,
#    'apyBase': 2.91547,
#    'apyReward': None,
#    'apy': 2.91547,
#    'rewardTokens': None,
#    'pool': '90bfb3c2-5d35-4959-a275-ba5085b08aa3',
#    'apyPct1D': 0.07199,
#    'apyPct7D': -0.14696,
#    'apyPct30D': -1.20218,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 81,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 3.45027,
#    'sigma': 0.09861,
#    'count': 145,
#    'outlier': False,
#    'underlyingTokens': ['0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'],
#    'il7d': None,
#    'apyBase7d': 2.79401,
#    'apyMean30d': 3.2416,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'balancer-v2',
#    'symbol': 'BAL-WETH',
#    'tvlUsd': 159424555,
#    'apyBase': 0.98624,
#    'apyReward': None,
#    'apy': 0.98624,
#    'rewardTokens': None,
#    'pool': '30eedaf4-83f7-418b-985b-89478d4b90e6',
#    'apyPct1D': 0.93899,
#    'apyPct7D': 0.34942,
#    'apyPct30D': 0.92501,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 51,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 2.24081,
#    'sigma': 0.85238,
#    'count': 641,
#    'outlier': False,
#    'underlyingTokens': ['0xba100000625a3754423978a60c9317c58a424e3d',
#     '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0.55242,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'makerdao',
#    'symbol': 'WBTC',
#    'tvlUsd': 157736235,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': '4dab1166-614a-429a-831f-4af70fd29c7d',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': 'WBTC-C',
#    'mu': 0,
#    'sigma': 0,
#    'count': 430,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'makerdao',
#    'symbol': 'WBTC',
#    'tvlUsd': 153216559,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': 'bd335b46-3daf-4507-adb2-6fd4337ea33b',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': 'WBTC-A',
#    'mu': 0,
#    'sigma': 0,
#    'count': 430,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Filecoin',
#    'project': 'glif',
#    'symbol': 'FIL',
#    'tvlUsd': 149024525,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 13.37098,
#    'rewardTokens': None,
#    'pool': '5317ec43-005e-472b-87a4-eb402b49d394',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': -0.46663,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 65,
#     'binnedConfidence': 2},
#    'poolMeta': 'Overcollateralized Filecoin staking pool',
#    'mu': 10.77841,
#    'sigma': 0.09343,
#    'count': 120,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 13.23006,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Polygon',
#    'project': 'lido',
#    'symbol': 'STMATIC',
#    'tvlUsd': 147323891,
#    'apyBase': 4.45,
#    'apyReward': None,
#    'apy': 4.45,
#    'rewardTokens': None,
#    'pool': 'bf3a7f07-80a0-4d5b-a311-b0f06f650f83',
#    'apyPct1D': -0.01,
#    'apyPct7D': -0.03,
#    'apyPct30D': 0.12,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Down',
#     'predictedProbability': 57.99999999999999,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 5.74795,
#    'sigma': 0.07769,
#    'count': 609,
#    'outlier': False,
#    'underlyingTokens': ['0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 4.41804,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'convex-finance',
#    'symbol': 'CVXCRV',
#    'tvlUsd': 140059825,
#    'apyBase': None,
#    'apyReward': 16.40388,
#    'apy': 16.40388,
#    'rewardTokens': ['0xd533a949740bb3306d119cc777fa900ba034cd52',
#     '0x4e3fbd56cd56c3e72c1403e103b45db9da5b9d2b',
#     '0x6c3F90f043a72FA612cbac8115EE7e52BDe6E490'],
#    'pool': 'ef32dd3b-a03b-4f79-9b65-8420d7e04ad0',
#    'apyPct1D': -0.04766,
#    'apyPct7D': 6.01254,
#    'apyPct30D': 2.19313,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 51,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 14.70304,
#    'sigma': 0.19581,
#    'count': 470,
#    'outlier': False,
#    'underlyingTokens': ['0xD533a949740bb3306d119CC777fa900bA034cd52'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 14.06992,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'uniswap-v3',
#    'symbol': 'USDC-WETH',
#    'tvlUsd': 139495247,
#    'apyBase': 19.36581,
#    'apyReward': None,
#    'apy': 19.36581,
#    'rewardTokens': None,
#    'pool': '665dc8bc-c79d-4800-97f7-304bf368e547',
#    'apyPct1D': 2.86963,
#    'apyPct7D': -5.77098,
#    'apyPct30D': -2.70792,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Down',
#     'predictedProbability': 65,
#     'binnedConfidence': 2},
#    'poolMeta': '0.05%',
#    'mu': 33.00963,
#    'sigma': 0.9311,
#    'count': 621,
#    'outlier': False,
#    'underlyingTokens': ['0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#     '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'],
#    'il7d': -0.06559,
#    'apyBase7d': 16.09455,
#    'apyMean30d': 29.62915,
#    'volumeUsd1d': 148024009.90173,
#    'volumeUsd7d': 1448820063.0683,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'convex-finance',
#    'symbol': 'ETH-STETH',
#    'tvlUsd': 129127044,
#    'apyBase': 1.68,
#    'apyReward': 1.61165,
#    'apy': 3.29165,
#    'rewardTokens': ['0xd533a949740bb3306d119cc777fa900ba034cd52',
#     '0x4e3fbd56cd56c3e72c1403e103b45db9da5b9d2b',
#     '0x5A98FcBEA516Cf06857215779Fd812CA3beF1B32',
#     '0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0'],
#    'pool': '5ce23e7e-3800-4c9c-ad30-6db3db0515a1',
#    'apyPct1D': 0.04799,
#    'apyPct7D': -0.08258,
#    'apyPct30D': -0.43202,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 77,
#     'binnedConfidence': 2},
#    'poolMeta': None,
#    'mu': 5.03471,
#    'sigma': 0.1016,
#    'count': 689,
#    'outlier': False,
#    'underlyingTokens': ['0xEeeeeEeeeEeEeeEeEeEeeEEEeeeeEeeeeeeeEEeE',
#     '0xae7ab96520DE3A18E5e111B5EaAb095312D7fE84'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 3.47883,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
# ...
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Down',
#     'predictedProbability': 96,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 3.24507,
#    'sigma': 0.31128,
#    'count': 593,
#    'outlier': False,
#    'underlyingTokens': ['0x823556202e86763853b40e9cde725f412e294689',
#     '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'],
#    'il7d': -1.9614,
#    'apyBase7d': 6.88185,
#    'apyMean30d': 5.47454,
#    'volumeUsd1d': 688322.50715,
#    'volumeUsd7d': 1460239.45171,
#    'apyBaseInception': None},
#   {'chain': 'Polygon',
#    'project': 'curve-dex',
#    'symbol': 'EURT-AM3CRV',
#    'tvlUsd': 3306170,
#    'apyBase': 0.00294,
#    'apyReward': 0.1788,
#    'apy': 0.18173,
#    'rewardTokens': ['0xD533a949740bb3306d119CC777fa900bA034cd52'],
#    'pool': '91f18c59-ddb0-4bbc-9a2c-bdde4aa0a4f9',
#    'apyPct1D': -0.04971,
#    'apyPct7D': -0.02819,
#    'apyPct30D': -0.01942,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Down',
#     'predictedProbability': 50,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 0.39631,
#    'sigma': 0.04041,
#    'count': 641,
#    'outlier': False,
#    'underlyingTokens': ['0x7BDF330f423Ea880FF95fC41A280fD5eCFD3D09f',
#     '0xE7a24EF0C5e95Ffb0f6684b813A78F2a3AD7D171'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0.20315,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'aave-v3',
#    'symbol': 'LDO',
#    'tvlUsd': 3305492,
#    'apyBase': 0.00201,
#    'apyReward': None,
#    'apy': 0.00201,
#    'rewardTokens': None,
#    'pool': '475e0e56-2648-4b75-82cb-e82f5983787a',
#    'apyPct1D': -0.00208,
#    'apyPct7D': -0.00058,
#    'apyPct30D': 0.00201,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 93,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 0.45817,
#    'sigma': 0.02525,
#    'count': 224,
#    'outlier': False,
#    'underlyingTokens': ['0x5A98FcBEA516Cf06857215779Fd812CA3beF1B32'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0.00119,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Arbitrum',
#    'project': 'synapse',
#    'symbol': 'NUSD-USDC-USDT',
#    'tvlUsd': 3301793,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 14.91262,
#    'rewardTokens': ['0x080F6AEd32Fc474DD5717105Dba5ea57268F46eb'],
#    'pool': '572a7c6b-6c51-41e0-84fd-0431015d4ea7',
#    'apyPct1D': 0.15472,
#    'apyPct7D': 1.53283,
#    'apyPct30D': 3.50335,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Down',
#     'predictedProbability': 97,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 7.26593,
#    'sigma': 0.15441,
#    'count': 293,
#    'outlier': False,
#    'underlyingTokens': ['0x2913E812Cf0dcCA30FB28E6Cac3d2DCFF4497688',
#     '0xFF970A61A04b1cA14834A43f5dE4533eBDDB5CC8',
#     '0xFd086bC7CD5C481DCC9C85ebE478A1C0b69FCbb9'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 12.21964,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Osmosis',
#    'project': 'osmosis-dex',
#    'symbol': 'USDC-USDT',
#    'tvlUsd': 3300466,
#    'apyBase': 1.53157,
#    'apyReward': None,
#    'apy': 1.53157,
#    'rewardTokens': [],
#    'pool': '7e12f6be-1d66-4644-9740-768a00b2321d',
#    'apyPct1D': -0.98371,
#    'apyPct7D': -1.93278,
#    'apyPct30D': 1.29054,
#    'stablecoin': True,
#    'ilRisk': 'no',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 55.00000000000001,
#     'binnedConfidence': 1},
#    'poolMeta': '14day',
#    'mu': 0.89168,
#    'sigma': 0.05125,
#    'count': 89,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': 2.05988,
#    'apyMean30d': 1.56846,
#    'volumeUsd1d': 1384900.19441,
#    'volumeUsd7d': 13074146.73238,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'aura',
#    'symbol': 'WETH-AURA',
#    'tvlUsd': 3298775,
#    'apyBase': 1.24,
#    'apyReward': 23.92614,
#    'apy': 25.16614,
#    'rewardTokens': ['0xC0c293ce456fF0ED870ADd98a0828Dd4d2903DBF',
#     '0xba100000625a3754423978a60c9317c58a424e3D',
#     '0xC0c293ce456fF0ED870ADd98a0828Dd4d2903DBF'],
#    'pool': 'adadd1cb-40ae-4692-b8f2-2a77a9e470f3',
#    'apyPct1D': -0.80896,
#    'apyPct7D': -9.46467,
#    'apyPct30D': 7.26589,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Down',
#     'predictedProbability': 78,
#     'binnedConfidence': 2},
#    'poolMeta': None,
#    'mu': 36.57957,
#    'sigma': 1.22149,
#    'count': 494,
#    'outlier': False,
#    'underlyingTokens': ['0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2',
#     '0xC0c293ce456fF0ED870ADd98a0828Dd4d2903DBF'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 28.58729,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Arbitrum',
#    'project': 'curve-dex',
#    'symbol': 'FRAX-USDC.E',
#    'tvlUsd': 3297174,
#    'apyBase': 0.16615,
#    'apyReward': 3.76789,
#    'apy': 3.93404,
#    'rewardTokens': ['0xD533a949740bb3306d119CC777fa900bA034cd52'],
#    'pool': '9bd24a7b-551a-4643-a017-39cf1a9130c4',
#    'apyPct1D': -0.73724,
#    'apyPct7D': -1.76164,
#    'apyPct30D': -3.04952,
#    'stablecoin': True,
#    'ilRisk': 'no',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Down',
#     'predictedProbability': 61,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 2.0485,
#    'sigma': 0.11988,
#    'count': 514,
#    'outlier': False,
#    'underlyingTokens': ['0x17FC002b466eEc40DaE837Fc4bE5c67993ddBd6F',
#     '0xFF970A61A04b1cA14834A43f5dE4533eBDDB5CC8'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 6.98927,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'stakehouse',
#    'symbol': 'DETH',
#    'tvlUsd': 3292556,
#    'apyBase': 2.72363,
#    'apyReward': None,
#    'apy': 2.72363,
#    'rewardTokens': None,
#    'pool': 'ce4d9ad8-696a-4cb4-8b63-0e230a76acb6',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': -0.45394,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 56.00000000000001,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 3.2607,
#    'sigma': 0.02255,
#    'count': 167,
#    'outlier': False,
#    'underlyingTokens': ['0x0000000000000000000000000000000000000000'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 2.91124,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'ipor',
#    'symbol': 'DAI',
#    'tvlUsd': 3288475,
#    'apyBase': 3.57066,
#    'apyReward': 1.60582,
#    'apy': 5.17647,
#    'rewardTokens': ['0x1e4746dc744503b53b4a082cb3607b169a289090'],
#    'pool': '9ba4ea64-d9f4-4753-9b6e-d2de21b0c6db',
#    'apyPct1D': -0.69979,
#    'apyPct7D': -0.9031,
#    'apyPct30D': -3.75768,
#    'stablecoin': True,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 82,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 9.79295,
#    'sigma': 0.3153,
#    'count': 429,
#    'outlier': False,
#    'underlyingTokens': ['0x6b175474e89094c44da98b954eedeac495271d0f'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 7.53313,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'uniswap-v3',
#    'symbol': 'WETH-SWETH',
#    'tvlUsd': 3279771,
#    'apyBase': 0.70651,
#    'apyReward': None,
#    'apy': 0.70651,
#    'rewardTokens': None,
#    'pool': '64e26366-3582-439c-b1de-b7cf84cf2749',
#    'apyPct1D': -3.07476,
#    'apyPct7D': -0.21687,
#    'apyPct30D': 0.53637,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Down',
#     'predictedProbability': 56.99999999999999,
#     'binnedConfidence': 1},
#    'poolMeta': '0.05%',
#    'mu': 1.51731,
#    'sigma': 0.17091,
#    'count': 209,
#    'outlier': False,
#    'underlyingTokens': ['0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#     '0xf951e335afb289353dc249e82926178eac7ded78'],
#    'il7d': -0.0024,
#    'apyBase7d': 0.05035,
#    'apyMean30d': 3.41144,
#    'volumeUsd1d': 126969.64372,
#    'volumeUsd7d': 3073960.34434,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'curve-dex',
#    'symbol': 'ETH-ANKRETH',
#    'tvlUsd': 3276641,
#    'apyBase': 3.23,
#    'apyReward': 0.12665,
#    'apy': 3.35665,
#    'rewardTokens': ['0xD533a949740bb3306d119CC777fa900bA034cd52'],
#    'pool': '83fcc624-ff58-4c3a-9b10-b8cc9d0da285',
#    'apyPct1D': -0.01216,
#    'apyPct7D': -0.88876,
#    'apyPct30D': 0.17596,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 62,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 3.20428,
#    'sigma': 0.06453,
#    'count': 685,
#    'outlier': False,
#    'underlyingTokens': ['0xEeeeeEeeeEeEeeEeEeEeeEEEeeeeEeeeeeeeEEeE',
#     '0xE95A203B1a91a908F9B9CE46459d101078c2c3cb'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 3.76373,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'silo-finance',
#    'symbol': 'CBETH',
#    'tvlUsd': 3270957,
#    'apyBase': 0,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': '372f90c9-7e31-4ce6-bcae-9e9be1925977',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 0.00046,
#    'sigma': 9e-05,
#    'count': 395,
#    'outlier': False,
#    'underlyingTokens': ['0xBe9895146f7AF43049ca1c1AE358B0541Ea49704',
#     '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Canto',
#    'project': 'canto-lending',
#    'symbol': 'USDT',
#    'tvlUsd': 3269457,
#    'apyBase': 1e-05,
#    'apyReward': 0,
#    'apy': 1e-05,
#    'rewardTokens': ['0x826551890Dc65655a0Aceca109aB11AbDbD7a07B'],
#    'pool': '945afa2b-4f81-422f-8f51-dc41c8aeb930',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': None,
#    'stablecoin': True,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 81,
#     'binnedConfidence': 3},
#    'poolMeta': None,
#    'mu': 3.87329,
#    'sigma': 0.15093,
#    'count': 382,
#    'outlier': False,
#    'underlyingTokens': ['0xd567B3d7B8FE3C79a1AD8dA978812cfC4Fa05e75'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 4e-05,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'angle',
#    'symbol': 'WSTETH',
#    'tvlUsd': 3266828,
#    'apyBase': None,
#    'apyReward': None,
#    'apy': 0,
#    'rewardTokens': None,
#    'pool': '53bad0ea-85ce-4159-befb-9caad52bbaa8',
#    'apyPct1D': 0,
#    'apyPct7D': 0,
#    'apyPct30D': 0,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': None,
#     'predictedProbability': None,
#     'binnedConfidence': None},
#    'poolMeta': None,
#    'mu': 0,
#    'sigma': 0,
#    'count': 366,
#    'outlier': False,
#    'underlyingTokens': None,
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'uniswap-v3',
#    'symbol': 'ΜBAYC-WETH',
#    'tvlUsd': 3265704,
#    'apyBase': 4.65039,
#    'apyReward': None,
#    'apy': 4.65039,
#    'rewardTokens': None,
#    'pool': 'badd232e-9339-4fcf-8dc8-ff64e82a83aa',
#    'apyPct1D': -0.31042,
#    'apyPct7D': -0.11452,
#    'apyPct30D': -5.25946,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 84,
#     'binnedConfidence': 3},
#    'poolMeta': '0.3%',
#    'mu': 23.71536,
#    'sigma': 1.04485,
#    'count': 74,
#    'outlier': False,
#    'underlyingTokens': ['0x1e610de0d7acfa1d820024948a91d96c5c9ce6b9',
#     '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'],
#    'il7d': -0.01192,
#    'apyBase7d': 5.35036,
#    'apyMean30d': 8.9142,
#    'volumeUsd1d': 138692.29144,
#    'volumeUsd7d': 871688.57061,
#    'apyBaseInception': None},
#   {'chain': 'Ethereum',
#    'project': 'convex-finance',
#    'symbol': 'XAI-FRAXBP',
#    'tvlUsd': 3264675,
#    'apyBase': 0.08,
#    'apyReward': 7.4589,
#    'apy': 7.5389,
#    'rewardTokens': ['0xd533a949740bb3306d119cc777fa900ba034cd52',
#     '0x4e3fbd56cd56c3e72c1403e103b45db9da5b9d2b'],
#    'pool': '881d89ac-1086-46c0-9358-617cecfba141',
#    'apyPct1D': 0.12677,
#    'apyPct7D': -2.1978,
#    'apyPct30D': 0.84568,
#    'stablecoin': True,
#    'ilRisk': 'no',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Down',
#     'predictedProbability': 54,
#     'binnedConfidence': 1},
#    'poolMeta': None,
#    'mu': 6.38498,
#    'sigma': 0.11621,
#    'count': 272,
#    'outlier': False,
#    'underlyingTokens': ['0xd7C9F0e536dC865Ae858b0C0453Fe76D13c3bEAc',
#     '0x3175Df0976dFA876431C2E9eE6Bc45b65d3473CC'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 8.17009,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Avalanche',
#    'project': 'trader-joe-dex',
#    'symbol': 'WAVAX-USDT.E',
#    'tvlUsd': 3262804,
#    'apyBase': 18.52848,
#    'apyReward': None,
#    'apy': 18.52848,
#    'rewardTokens': [],
#    'pool': 'f3264bbc-11de-45ea-b6b7-318c553e6b39',
#    'apyPct1D': 1.1452,
#    'apyPct7D': 0.89742,
#    'apyPct30D': 15.0291,
#    'stablecoin': False,
#    'ilRisk': 'yes',
#    'exposure': 'multi',
#    'predictions': {'predictedClass': 'Down',
#     'predictedProbability': 66,
#     'binnedConfidence': 2},
#    'poolMeta': None,
#    'mu': 15.63657,
#    'sigma': 0.80047,
#    'count': 674,
#    'outlier': False,
#    'underlyingTokens': ['0xb31f66aa3c1e785363f0875a1b74e27b85fd66c7',
#     '0xc7198437980c041c805a1edcba50c1ce5db95118'],
#    'il7d': None,
#    'apyBase7d': 28.31171,
#    'apyMean30d': 29.88332,
#    'volumeUsd1d': 552098.71381,
#    'volumeUsd7d': 5921510.11857,
#    'apyBaseInception': None},
#   {'chain': 'Optimism',
#    'project': 'aave-v3',
#    'symbol': 'LINK',
#    'tvlUsd': 3255364,
#    'apyBase': 0.04414,
#    'apyReward': None,
#    'apy': 0.04414,
#    'rewardTokens': None,
#    'pool': 'fe084859-2384-4daf-86ec-63f5f8dcdaaa',
#    'apyPct1D': 0.00042,
#    'apyPct7D': 0.0022,
#    'apyPct30D': 0.01118,
#    'stablecoin': False,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Stable/Up',
#     'predictedProbability': 77,
#     'binnedConfidence': 2},
#    'poolMeta': None,
#    'mu': 0.12744,
#    'sigma': 0.00697,
#    'count': 512,
#    'outlier': False,
#    'underlyingTokens': ['0x350a791bfc2c21f9ed5d10980dad2e2638ffa7f6'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 0.03549,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   {'chain': 'Optimism',
#    'project': 'idle',
#    'symbol': 'USDT',
#    'tvlUsd': 3253281,
#    'apyBase': 16.41245,
#    'apyReward': 3.13,
#    'apy': 19.54245,
#    'rewardTokens': ['0x4200000000000000000000000000000000000042'],
#    'pool': '21c278fe-aec3-4848-af48-2d7b14558c76',
#    'apyPct1D': 0.08097,
#    'apyPct7D': -2.2104,
#    'apyPct30D': 0.13003,
#    'stablecoin': True,
#    'ilRisk': 'no',
#    'exposure': 'single',
#    'predictions': {'predictedClass': 'Down',
#     'predictedProbability': 50,
#     'binnedConfidence': 1},
#    'poolMeta': 'Clearpool Portofino Junior Tranche',
#    'mu': 19.55845,
#    'sigma': 0.19267,
#    'count': 57,
#    'outlier': False,
#    'underlyingTokens': ['0x94b008aA00579c1307B0EF2c499aD98a8ce58e58'],
#    'il7d': None,
#    'apyBase7d': None,
#    'apyMean30d': 20.67626,
#    'volumeUsd1d': None,
#    'volumeUsd7d': None,
#    'apyBaseInception': None},
#   ...]}

# %%
data = data['data']
# data = data[0]
# del data['predictions']

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#            chain             project       symbol       tvlUsd  apyBase  \
# 0       Ethereum                lido        STETH  19972627403  3.60000
# 1      Avalanche            joe-v2.1  DWEEB-WAVAX  18101870530  0.00000
# 2         Solana             raydium  SOL-UNKNOWN  11615990503  0.00000
# 3           Tron            justlend          BTC   4414398191  0.00050
# 4       Ethereum         rocket-pool         RETH   2535309195  3.11568
# ...          ...                 ...          ...          ...      ...
# 14140   Moonbeam               beefy   FLARE-GLMR        10000      NaN
# 14141    Polygon       quickswap-dex  WMATIC-BOOM        10000  0.00000
# 14142        BSC  pancakeswap-amm-v3     LTC-USDT        10000  0.00000
# 14143   Arbitrum          camelot-v2  SHICOD-WETH        10000  0.00000
# 14144     Solana                orca    USDC-USDT        10000  0.00033
#
#        apyReward       apy                          rewardTokens  \
# 0            NaN   3.60000                                  None
# 1            NaN   0.00000                                  None
# 2            NaN   0.00000                                  None
# 3            0.0   0.00050  [TPYmHEhy5n8TCEfYGqW2rPxsghSfzghPDn]
# 4            NaN   3.11568                                  None
# ...          ...       ...                                   ...
# 14140        NaN  83.28531                                  None
# 14141        NaN   0.00000                                  None
# 14142        NaN   0.00000                                  None
# 14143        NaN   0.00000                                    []
# 14144        NaN   0.00033                                    []
#
#                                        pool  apyPct1D  ...    sigma  count  \
# 0      747c1d2a-c668-4682-b9f9-296708a3dd90       NaN  ...  0.04738    587
# 1      35768c30-eae6-468f-8eb1-17fb707f851f       NaN  ...  0.00000      1
# 2      943cbe42-0c69-4a92-97db-86f732a3449a       NaN  ...  0.00000      1
# 3      71418c17-d2aa-4eff-b68a-806fff9ec951   0.00000  ...  0.00082    544
# 4      d4b3c522-6127-4b89-bedf-83641cdcd2eb   0.02136  ...  0.03908    350
# ...                                     ...       ...  ...      ...    ...
# 14140  122ce366-4aba-439f-855b-e4e665b1c667   6.67744  ...  1.26065    205
# 14141  04934485-a88a-409e-aed2-474fc1d113b2       NaN  ...  0.05945     22
# 14142  26a73a54-1336-44ac-9e79-c454b297c257   0.00000  ...  0.00000     12
# 14143  4068a877-ab0d-4d62-a6e0-8566738a2a98       NaN  ...  0.13794    104
# 14144  a4602b2e-90ce-455a-9d43-674a4dcfd3f6       NaN  ...  0.00002      4
#
#        outlier                                   underlyingTokens     il7d  \
# 0        False       [0x0000000000000000000000000000000000000000]      NaN
# 1        False  [0x3aa9d7ff037a2cf76162ec6001452b1c3261ab3e, 0...      NaN
# 2        False                                               None      NaN
# 3        False               [TN3W4H6rK2ce4vX9YnFQHwKENnHjoxb3m9]      NaN
# 4        False       [0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2]      NaN
# ...        ...                                                ...      ...
# 14140     True                                               None      NaN
# 14141    False  [0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, 0...      NaN
# 14142    False  [0x4338665cbb7b2485a8855a139b75d5e34ab0db94, 0... -0.00964
# 14143    False  [0x3bf0c8163dd1c22c862b1c887386f17aa4383e07, 0...      NaN
# 14144    False  [EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v,...  0.00000
#
#       apyBase7d apyMean30d  volumeUsd1d  volumeUsd7d  apyBaseInception
# 0           NaN    3.78182          NaN          NaN               NaN
# 1           NaN    0.00000     14.90332          NaN               NaN
# 2           NaN   53.30900          NaN          NaN               NaN
# 3           NaN    0.00049          NaN          NaN               NaN
# 4           NaN    3.43859          NaN          NaN               NaN
# ...         ...        ...          ...          ...               ...
# 14140       NaN   97.22064          NaN          NaN               NaN
# 14141   0.57875    0.31318          NaN    370.99598               NaN
# 14142   0.00000    0.00000          NaN          NaN               NaN
# 14143   0.00423    0.04031          NaN      2.70840               NaN
# 14144   0.00087    0.00068      0.43688      3.93585               NaN
#
# [14145 rows x 28 columns]

# %%
data
# Out:
# {'chain': 'Ethereum',
#  'project': 'lido',
#  'symbol': 'STETH',
#  'tvlUsd': 19972627403,
#  'apyBase': 3.6,
#  'apyReward': None,
#  'apy': 3.6,
#  'rewardTokens': None,
#  'pool': '747c1d2a-c668-4682-b9f9-296708a3dd90',
#  'apyPct1D': None,
#  'apyPct7D': None,
#  'apyPct30D': 0,
#  'stablecoin': False,
#  'ilRisk': 'no',
#  'exposure': 'single',
#  'poolMeta': None,
#  'mu': 4.4325,
#  'sigma': 0.04738,
#  'count': 587,
#  'outlier': False,
#  'underlyingTokens': ['0x0000000000000000000000000000000000000000'],
#  'il7d': None,
#  'apyBase7d': None,
#  'apyMean30d': 3.78182,
#  'volumeUsd1d': None,
#  'volumeUsd7d': None,
#  'apyBaseInception': None}
